# %%
# how to generate randomly sampled waveform

# %%
import numpy as np
import matplotlib.pyplot as plt

#  generate uniform sampled numbers 0-1
M1 = np.random.random(1000)
M2 = np.random.random(1000)

def get_waveform(m1, m2):
    # write some code below...
    return None

datasets = {}
for i, (m1, m2) in enumerate(zip(M1, M2)):
    data = {}
    # get_waveform : methid to generate GW event by  2D parameters
    waveform = get_waveform(m1=m1, 
                            m2=m2)
    data['waveform'] = waveform
    data['m1'] = m1
    data['m2'] = m2 
    datasets[i] = data
datasets
# device datasets into two parts: training set/ test set
# In general, length of training set is len(all datasets) * 0.8-0.7 -> 700-800 
#             length of test set is len(all datasets) * 0.2-0.3 -> 200-300 

# save datasets to file
# format: .hdf5(I reccomend), .csv, .txt, ...
plt.scatter(M1, M2)
plt.show()
# Out:
# {0: {'waveform': None, 'm1': 0.8153803336209108, 'm2': 0.9523963980008859},
#  1: {'waveform': None, 'm1': 0.3476646609449874, 'm2': 0.6940244471483221},
#  2: {'waveform': None, 'm1': 0.37260457759706533, 'm2': 0.4900678210825774},
#  3: {'waveform': None, 'm1': 0.12812964578779518, 'm2': 0.3610349566757185},
#  4: {'waveform': None, 'm1': 0.5955120891383072, 'm2': 0.007011918906554393},
#  5: {'waveform': None, 'm1': 0.6920297014228307, 'm2': 0.6534575192729882},
#  6: {'waveform': None, 'm1': 0.8160313034416089, 'm2': 0.3951577484510985},
#  7: {'waveform': None, 'm1': 0.756317889719484, 'm2': 0.12975523941878708},
#  8: {'waveform': None, 'm1': 0.5072949976050478, 'm2': 0.4131840480651735},
#  9: {'waveform': None, 'm1': 0.8664125154009034, 'm2': 0.3246042982762216},
#  10: {'waveform': None, 'm1': 0.3771055411136356, 'm2': 0.3625893536825191},
#  11: {'waveform': None, 'm1': 0.4849555775066753, 'm2': 0.8146988758641218},
# ...

# %%
plt.scatter(M1, M2)
plt.show()
